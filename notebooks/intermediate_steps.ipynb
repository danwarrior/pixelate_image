# %% [markdown]
# ## Libraries

# %%
import sys
sys.path.append('../code/')
from lib import utils

# %% [markdown]
# ## Load image

# %%
image_path = '../data/dylan.jpg'
dylan = utils.load_image(image_path)
utils.display_image(dylan)

# %% [markdown]
# ## Segmented image

# %%
# define te number of parcelations (clusters) to segment the image
k = 3
dylan_parcel = utils.parcelate_image(dylan, k)
dylan_smooth = utils.fill_parcelation(dylan_parcel, dylan, k)
utils.display_images_plt(dylan_parcel, dylan_smooth)
