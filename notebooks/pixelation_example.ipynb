# %% [markdown]
# # Pixelate image

# %% [markdown]
# ## Import libraries

# %%
import sys
sys.path.append('../code/')
from lib import utils

# %% [markdown]
# ## Load image

# %%
image_path = '../data/dylan.jpg'
dylan = utils.load_image(image_path)
utils.display_image(dylan)

# %% [markdown]
# ## Simple pixelation

# %%
pixel_dylan = utils.simple_pixelation(dylan, 80, 80)
utils.display_images_pair(dylan, pixel_dylan)

# %% [markdown]
# ## Smoot pixelation

# %%
k_pixel_dylan = utils.kMeans_pixelation(dylan, 8)

# %%
utils.display_images_pair(dylan, k_pixel_dylan)
